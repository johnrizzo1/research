# %%
# %pip install openbb

# %%
from openbb import obb
from datetime import datetime, timedelta
import os

# %%
obb.account.login(pat=os.environ.get("OPENBB_PAT"))
obb.user.credentials
# Out:
# Credentials
#
# benzinga_api_key: None
# fmp_api_key: **********
# fred_api_key: **********
# intrinio_api_key: None
# polygon_api_key: **********
# tiingo_token: None
# tradingeconomics_api_key: **********

# %%
now = datetime.now()
end_date = datetime(
    year=now.year,
    month=now.month,
    day=now.day)
delta = timedelta(days=30)
start_date = end_date - delta


output = obb.equity.price.historical("AAPL", start_date=start_date, end_date=end_date, provider='yfinance')
df = output.to_dataframe()
df.head()
df
# Out:
#                open      high     low   close    volume      vwap  adj_close  \
# date
# 2024-11-13  224.010  226.6500  222.76  225.12  48566217  224.6350     225.12
# 2024-11-14  225.020  228.8700  225.00  228.22  44923941  226.7775     228.22
# 2024-11-15  226.400  226.9200  224.27  225.00  47923700  225.6475     225.00
# 2024-11-18  225.250  229.7400  225.17  228.02  44686020  227.0450     228.02
# 2024-11-19  226.980  230.1600  226.66  228.28  36211800  228.0200     228.28
# 2024-11-20  228.060  229.9300  225.89  229.00  35169600  228.2200     229.00
# 2024-11-21  228.880  230.1600  225.71  228.52  42108327  228.3175     228.52
# 2024-11-22  228.060  230.7200  228.06  229.87  38168300  229.1775     229.87
# 2024-11-25  231.460  233.2500  229.74  232.87  90152832  231.8300     232.87
# 2024-11-26  233.330  235.5700  233.33  235.06  45986200  234.3225     235.06
# 2024-11-27  234.470  235.6900  233.81  234.93  33498439  234.7250     234.93
# 2024-11-29  234.810  237.8100  233.97  237.33  28481400  235.9800     237.33
# 2024-12-02  237.270  240.7900  237.16  239.59  48137103  238.7025     239.59
# 2024-12-03  239.810  242.7600  238.90  242.65  38861017  241.0300     242.65
# 2024-12-04  242.870  244.1100  241.25  243.01  44383935  242.8100     243.01
# 2024-12-05  243.990  244.5400  242.13  243.04  40033900  243.4250     243.04
# 2024-12-06  242.910  244.6300  242.08  242.84  36870619  243.1150     242.84
# 2024-12-09  241.830  247.2400  241.75  246.75  44649232  244.3925     246.75
# 2024-12-10  246.890  248.2100  245.34  247.77  36914806  247.0525     247.77
# 2024-12-11  247.960  250.8000  246.26  246.49  45205814  247.8775     246.49
# 2024-12-12  246.890  248.7400  245.68  247.96  29983256  247.3175     247.96
# 2024-12-13  247.815  249.2902  246.24  247.71  16227645  247.7500     247.71
#
#             unadjusted_volume  change  change_percent
# date
# 2024-11-13         48566217.0   1.110        0.004955
# 2024-11-14         44923941.0   3.200        0.014200
# 2024-11-15         47923700.0  -1.400       -0.006184
# 2024-11-18         44686020.0   2.770        0.012300
# 2024-11-19         36211800.0   1.300        0.005727
# 2024-11-20         35169600.0   0.940        0.004122
# 2024-11-21         42108327.0  -0.360       -0.001573
# 2024-11-22         38168300.0   1.810        0.007937
# 2024-11-25         90152832.0   1.410        0.006092
# 2024-11-26         45986200.0   1.730        0.007414
# 2024-11-27         33498439.0   0.465        0.001962
# 2024-11-29         28481400.0   2.530        0.010700
# 2024-12-02         48137103.0   2.320        0.009778
# 2024-12-03         38861017.0   2.840        0.011800
# 2024-12-04         44383935.0   0.140        0.000576
# 2024-12-05         40033900.0  -0.950       -0.003894
# 2024-12-06         36870619.0  -0.065       -0.000288
# 2024-12-09         44649232.0   4.920        0.020300
# 2024-12-10         36914806.0   0.880        0.003564
# 2024-12-11         45205814.0  -1.470       -0.005928
# 2024-12-12         29983256.0   1.070        0.004334
# 2024-12-13         16227645.0  -0.105       -0.000424

# %%
obb.equity.search("JPMorgan", provider="sec").to_df().head(3)

# %%
obb.etf.search("gold", provider="fmp").to_df().iloc[-5:]

# %%
all_companies = obb.equity.search("", provider="sec")
print(len(all_companies.results))
all_companies.to_df().head(10)

# %%
results = obb.equity.screener(country="US"
                              # , sector="technology"
                              # , industry="semiconductors"
                              , exchange="nasdaq"
                              , provider="nasdaq"
                              ).to_df()
display(len(results))
results.convert_dtypes()
